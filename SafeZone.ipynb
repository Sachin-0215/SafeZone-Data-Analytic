# %% [markdown]
# # Data Analysis of our Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl

# %%
df1 = pd.read_csv("newData.csv")
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1 District         Event Circle Police Station  \
# 0              0             0  LUCKNOW  P01042100004     C1            PS1
# 1              1             1  LUCKNOW  P01042104316     C1            PS1
# 2              2             2  LUCKNOW  P01042104847     C1            PS1
# 3              3             3  LUCKNOW  P01042105074     C1            PS1
# 4              4             4  LUCKNOW  P01042105152     C1            PS1
# ...          ...           ...      ...           ...    ...            ...
# 5118        5118          5123  LUCKNOW  P30062111143     C2            PS4
# 5119        5119          5124  LUCKNOW  P30062111164     C2            PS4
# 5120        5120          5125  LUCKNOW  P30062111341     C2            PS4
# 5121        5121          5126  LUCKNOW  P30062111700     C2            PS4
# 5122        5122          5127  LUCKNOW  P30062118243     C2            PS4
#
#      Caller Source                  Event Type  \
# 0            PHONE  Information Against Police
# 1            PHONE            Threat In Person
# 2            PHONE                     Dispute
# 3            PHONE                    Gambling
# 4            PHONE            Threat In Person
# ...            ...                         ...
# 5118         PHONE                     Dispute
# 5119         PHONE                     Dispute
# 5120         PHONE                Cyber Crimes
# 5121         PHONE                     Robbery
# 5122         PHONE            Threat In Person
#
#                        Event Sub-Type     Create Date/Time  Latitude  \
# 0                  Misbehavior By Prv  2021-04-01 00:00:00    26.834
# 1                              Attack  2021-04-01 12:09:00    26.828
# 2                 Dispute In Hospital  2021-04-01 12:51:00    26.840
# 3                          Play Cards  2021-04-01 13:10:00    26.828
# 4                              Attack  2021-04-01 13:18:00    26.834
# ...                               ...                  ...       ...
# 5118                    With Neighbor  2021-06-30 17:59:54    26.866
# 5119  Dispute Between Ride And Driver  2021-06-30 18:01:05    26.864
# 5120             Bank Account Hacking  2021-06-30 18:10:59    26.864
# 5121                          On Road  2021-06-30 18:33:39    26.873
# 5122              Threatening To Kill  2021-06-30 23:59:08    26.863
#
#       Longitude
# 0        81.008
# 1        81.014
# 2        81.009
# 3        81.002
# 4        81.033
# ...         ...
# 5118     81.026
# 5119     81.006
# 5120     80.998
# 5121     81.023
# 5122     81.001
#
# [5123 rows x 12 columns]

# %%
df1['Create Date/Time'] = pd.to_datetime(df1['Create Date/Time'], format="%Y-%m-%d %H:%M:%S")

# %% [markdown]
# # Split Date Day And Time in different columns

# %%
df1['year']  = df1['Create Date/Time'].dt.year
df1['month'] = df1['Create Date/Time'].dt.month
df1['day']   = df1['Create Date/Time'].dt.day
df1['hour'] = df1['Create Date/Time'].dt.hour
df1['minute'] = df1['Create Date/Time'].dt.minute
df1['second'] = df1['Create Date/Time'].dt.second
df1['day_of_week']  = df1['Create Date/Time'].dt.dayofweek
df1.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1 District         Event Circle Police Station  \
# 0           0             0  LUCKNOW  P01042100004     C1            PS1
# 1           1             1  LUCKNOW  P01042104316     C1            PS1
# 2           2             2  LUCKNOW  P01042104847     C1            PS1
# 3           3             3  LUCKNOW  P01042105074     C1            PS1
# 4           4             4  LUCKNOW  P01042105152     C1            PS1
#
#   Caller Source                  Event Type       Event Sub-Type  \
# 0         PHONE  Information Against Police   Misbehavior By Prv
# 1         PHONE            Threat In Person               Attack
# 2         PHONE                     Dispute  Dispute In Hospital
# 3         PHONE                    Gambling           Play Cards
# 4         PHONE            Threat In Person               Attack
#
#      Create Date/Time  Latitude  Longitude  year  month  day  hour  minute  \
# 0 2021-04-01 00:00:00    26.834     81.008  2021      4    1     0       0
# 1 2021-04-01 12:09:00    26.828     81.014  2021      4    1    12       9
# 2 2021-04-01 12:51:00    26.840     81.009  2021      4    1    12      51
# 3 2021-04-01 13:10:00    26.828     81.002  2021      4    1    13      10
# 4 2021-04-01 13:18:00    26.834     81.033  2021      4    1    13      18
#
#    second  day_of_week
# 0       0            3
# 1       0            3
# 2       0            3
# 3       0            3
# 4       0            3

# %%
df1['DayOfWeek'] = df1['Create Date/Time'].dt.day_name()
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1 District         Event Circle Police Station  \
# 0              0             0  LUCKNOW  P01042100004     C1            PS1
# 1              1             1  LUCKNOW  P01042104316     C1            PS1
# 2              2             2  LUCKNOW  P01042104847     C1            PS1
# 3              3             3  LUCKNOW  P01042105074     C1            PS1
# 4              4             4  LUCKNOW  P01042105152     C1            PS1
# ...          ...           ...      ...           ...    ...            ...
# 5118        5118          5123  LUCKNOW  P30062111143     C2            PS4
# 5119        5119          5124  LUCKNOW  P30062111164     C2            PS4
# 5120        5120          5125  LUCKNOW  P30062111341     C2            PS4
# 5121        5121          5126  LUCKNOW  P30062111700     C2            PS4
# 5122        5122          5127  LUCKNOW  P30062118243     C2            PS4
#
#      Caller Source                  Event Type  \
# 0            PHONE  Information Against Police
# 1            PHONE            Threat In Person
# 2            PHONE                     Dispute
# 3            PHONE                    Gambling
# 4            PHONE            Threat In Person
# ...            ...                         ...
# 5118         PHONE                     Dispute
# 5119         PHONE                     Dispute
# 5120         PHONE                Cyber Crimes
# 5121         PHONE                     Robbery
# 5122         PHONE            Threat In Person
#
#                        Event Sub-Type    Create Date/Time  Latitude  \
# 0                  Misbehavior By Prv 2021-04-01 00:00:00    26.834
# 1                              Attack 2021-04-01 12:09:00    26.828
# 2                 Dispute In Hospital 2021-04-01 12:51:00    26.840
# 3                          Play Cards 2021-04-01 13:10:00    26.828
# 4                              Attack 2021-04-01 13:18:00    26.834
# ...                               ...                 ...       ...
# 5118                    With Neighbor 2021-06-30 17:59:54    26.866
# 5119  Dispute Between Ride And Driver 2021-06-30 18:01:05    26.864
# 5120             Bank Account Hacking 2021-06-30 18:10:59    26.864
# 5121                          On Road 2021-06-30 18:33:39    26.873
# 5122              Threatening To Kill 2021-06-30 23:59:08    26.863
#
#       Longitude  year  month  day  hour  minute  second  day_of_week  \
# 0        81.008  2021      4    1     0       0       0            3
# 1        81.014  2021      4    1    12       9       0            3
# 2        81.009  2021      4    1    12      51       0            3
# 3        81.002  2021      4    1    13      10       0            3
# 4        81.033  2021      4    1    13      18       0            3
# ...         ...   ...    ...  ...   ...     ...     ...          ...
# 5118     81.026  2021      6   30    17      59      54            2
# 5119     81.006  2021      6   30    18       1       5            2
# 5120     80.998  2021      6   30    18      10      59            2
# 5121     81.023  2021      6   30    18      33      39            2
# 5122     81.001  2021      6   30    23      59       8            2
#
#       DayOfWeek
# 0      Thursday
# 1      Thursday
# 2      Thursday
# 3      Thursday
# 4      Thursday
# ...         ...
# 5118  Wednesday
# 5119  Wednesday
# 5120  Wednesday
# 5121  Wednesday
# 5122  Wednesday
#
# [5123 rows x 20 columns]

# %%
df1.drop(['District', 'Caller Source'], axis = 1)   #dropped unncecessary columns from table
# Out:
#       Unnamed: 0  Unnamed: 0.1         Event Circle Police Station  \
# 0              0             0  P01042100004     C1            PS1
# 1              1             1  P01042104316     C1            PS1
# 2              2             2  P01042104847     C1            PS1
# 3              3             3  P01042105074     C1            PS1
# 4              4             4  P01042105152     C1            PS1
# ...          ...           ...           ...    ...            ...
# 5118        5118          5123  P30062111143     C2            PS4
# 5119        5119          5124  P30062111164     C2            PS4
# 5120        5120          5125  P30062111341     C2            PS4
# 5121        5121          5126  P30062111700     C2            PS4
# 5122        5122          5127  P30062118243     C2            PS4
#
#                       Event Type                   Event Sub-Type  \
# 0     Information Against Police               Misbehavior By Prv
# 1               Threat In Person                           Attack
# 2                        Dispute              Dispute In Hospital
# 3                       Gambling                       Play Cards
# 4               Threat In Person                           Attack
# ...                          ...                              ...
# 5118                     Dispute                    With Neighbor
# 5119                     Dispute  Dispute Between Ride And Driver
# 5120                Cyber Crimes             Bank Account Hacking
# 5121                     Robbery                          On Road
# 5122            Threat In Person              Threatening To Kill
#
#         Create Date/Time  Latitude  Longitude  year  month  day  hour  minute  \
# 0    2021-04-01 00:00:00    26.834     81.008  2021      4    1     0       0
# 1    2021-04-01 12:09:00    26.828     81.014  2021      4    1    12       9
# 2    2021-04-01 12:51:00    26.840     81.009  2021      4    1    12      51
# 3    2021-04-01 13:10:00    26.828     81.002  2021      4    1    13      10
# 4    2021-04-01 13:18:00    26.834     81.033  2021      4    1    13      18
# ...                  ...       ...        ...   ...    ...  ...   ...     ...
# 5118 2021-06-30 17:59:54    26.866     81.026  2021      6   30    17      59
# 5119 2021-06-30 18:01:05    26.864     81.006  2021      6   30    18       1
# 5120 2021-06-30 18:10:59    26.864     80.998  2021      6   30    18      10
# 5121 2021-06-30 18:33:39    26.873     81.023  2021      6   30    18      33
# 5122 2021-06-30 23:59:08    26.863     81.001  2021      6   30    23      59
#
#       second  day_of_week  DayOfWeek
# 0          0            3   Thursday
# 1          0            3   Thursday
# 2          0            3   Thursday
# 3          0            3   Thursday
# 4          0            3   Thursday
# ...      ...          ...        ...
# 5118      54            2  Wednesday
# 5119       5            2  Wednesday
# 5120      59            2  Wednesday
# 5121      39            2  Wednesday
# 5122       8            2  Wednesday
#
# [5123 rows x 18 columns]

# %%
df1['Create Date/Time'].max()-df1['Create Date/Time'].min()    #TOTAL DAYS
# Out:
# Timedelta('90 days 23:59:08')

# %%
df1['Dates'] = pd.to_datetime(df1['Create Date/Time']).dt.date
df1['Time'] = pd.to_datetime(df1['Create Date/Time']).dt.time
df1.drop(['Create Date/Time'],axis=1)
# Out:
#       Unnamed: 0  Unnamed: 0.1 District         Event Circle Police Station  \
# 0              0             0  LUCKNOW  P01042100004     C1            PS1
# 1              1             1  LUCKNOW  P01042104316     C1            PS1
# 2              2             2  LUCKNOW  P01042104847     C1            PS1
# 3              3             3  LUCKNOW  P01042105074     C1            PS1
# 4              4             4  LUCKNOW  P01042105152     C1            PS1
# ...          ...           ...      ...           ...    ...            ...
# 5118        5118          5123  LUCKNOW  P30062111143     C2            PS4
# 5119        5119          5124  LUCKNOW  P30062111164     C2            PS4
# 5120        5120          5125  LUCKNOW  P30062111341     C2            PS4
# 5121        5121          5126  LUCKNOW  P30062111700     C2            PS4
# 5122        5122          5127  LUCKNOW  P30062118243     C2            PS4
#
#      Caller Source                  Event Type  \
# 0            PHONE  Information Against Police
# 1            PHONE            Threat In Person
# 2            PHONE                     Dispute
# 3            PHONE                    Gambling
# 4            PHONE            Threat In Person
# ...            ...                         ...
# 5118         PHONE                     Dispute
# 5119         PHONE                     Dispute
# 5120         PHONE                Cyber Crimes
# 5121         PHONE                     Robbery
# 5122         PHONE            Threat In Person
#
#                        Event Sub-Type  Latitude  ...  year  month  day  hour  \
# 0                  Misbehavior By Prv    26.834  ...  2021      4    1     0
# 1                              Attack    26.828  ...  2021      4    1    12
# 2                 Dispute In Hospital    26.840  ...  2021      4    1    12
# 3                          Play Cards    26.828  ...  2021      4    1    13
# 4                              Attack    26.834  ...  2021      4    1    13
# ...                               ...       ...  ...   ...    ...  ...   ...
# 5118                    With Neighbor    26.866  ...  2021      6   30    17
# 5119  Dispute Between Ride And Driver    26.864  ...  2021      6   30    18
# 5120             Bank Account Hacking    26.864  ...  2021      6   30    18
# 5121                          On Road    26.873  ...  2021      6   30    18
# 5122              Threatening To Kill    26.863  ...  2021      6   30    23
#
#       minute  second  day_of_week  DayOfWeek       Dates      Time
# 0          0       0            3   Thursday  2021-04-01  00:00:00
# 1          9       0            3   Thursday  2021-04-01  12:09:00
# 2         51       0            3   Thursday  2021-04-01  12:51:00
# 3         10       0            3   Thursday  2021-04-01  13:10:00
# 4         18       0            3   Thursday  2021-04-01  13:18:00
# ...      ...     ...          ...        ...         ...       ...
# 5118      59      54            2  Wednesday  2021-06-30  17:59:54
# 5119       1       5            2  Wednesday  2021-06-30  18:01:05
# 5120      10      59            2  Wednesday  2021-06-30  18:10:59
# 5121      33      39            2  Wednesday  2021-06-30  18:33:39
# 5122      59       8            2  Wednesday  2021-06-30  23:59:08
#
# [5123 rows x 21 columns]

# %% [markdown]
# # Functions for filtering data Event Wise

# %%
# filter by days of week and Event Type
def EventDaysInfo(EventType,EventDay):
      nEvent = df1[(df1["Event Type"] == EventType) & (df1['DayOfWeek']==EventDay)]
      print("Total Events of",EventType, "ocuured on ",EventDay, "is " ,len(nEvent))

# %% [markdown]
# EventDaysInfo('Child Crime','Monday')
# EventDaysInfo('Medium Fire','Tuesday')
# EventDaysInfo('Pick Pocket','Wed')
# EventDaysInfo('Crime On Phone Mobile Social Media Internet','Thursday')

# %% [markdown]
# # Graphs

# %% [markdown]
# # Week Day wise Total Cases

# %%
a1=len(df1[(df1['DayOfWeek']=='Monday')])
a2=len(df1[(df1['DayOfWeek']=='Tuesday')])
a3=len(df1[(df1['DayOfWeek']=='Wednesday')])
a4=len(df1[(df1['DayOfWeek']=='Thursday')])
a5=len(df1[(df1['DayOfWeek']=='Friday')])
a6=len(df1[(df1['DayOfWeek']=='Saturday')])
a7=len(df1[(df1['DayOfWeek']=='Sunday')])

plt.figure(figsize=(8,5))

ndays=[a1,a2,a3,a4,a5,a6,a7]
nocases = [697, 751, 737, 739, 733, 730, 736]
days = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
plt.plot(days,nocases,"yo:",linewidth=3 ,markersize=10,label="Level of Cases")
plt.title("Day wise cases",fontsize=15) #changes fontsize of the text
plt.xlabel("Days",fontsize=13)        
plt.ylabel("Number of cases",fontsize=13)
plt.legend(loc=4) #set the location of the text
plt.grid(color='w', linestyle='-.', linewidth=5)

# %% [markdown]
# # Month Wise Total Cases

# %%
plt.figure(figsize=(8,5))
months = ['April', 'May','June']
Each_Month_Cases=[2070, 1434, 1619]


# plt.plot(day,delhi_temperature,"mo--",linewidth=3 ,markersize=10,label="delhi_Temp line")
plt.plot(months,Each_Month_Cases,"red",linewidth=3 ,markersize=10,label="Level of Cases")
plt.title("Month wise cases",fontsize=15) #changes fontsize of the text
plt.xlabel("Month",fontsize=13)        
plt.ylabel("Number of cases",fontsize=13)
plt.legend(loc=4) #set the location of the text
plt.grid(color='blue', linestyle='--', linewidth=1)

# %%
months = ['April', 'May','June']
Each_Month_Cases=[2070, 1434, 1619]
explode=[0.3,0.2,0]
color=["c", "b", "r"]
textprops={"fontsize":15}
plt.pie(Each_Month_Cases,labels=months, explode=explode,colors = color,autopct="%0.3f%%"
        ,shadow=True,radius=1.4,startangle=270,textprops = textprops)
plt.show()

# %% [markdown]
# # Most Frequents Event Types

# %%
df1['Event Type'].value_counts()[:10].plot(kind='bar', figsize=(20, 10), rot=20)
# Out:
# <AxesSubplot:>

# %%
Event_type = ['Dispute','Domestic Violence','Threat In Person','Corona','Theft']


for i in Event_type:
  c1 = len(df1[(df1["Event Type"] == i) & (df1['DayOfWeek']=="Monday")])
  c2 = len(df1[(df1["Event Type"] == i) & (df1['DayOfWeek']=="Tuesday")])
  c3 = len(df1[(df1["Event Type"] == i) & (df1['DayOfWeek']=="Wednesday")])
  c4 = len(df1[(df1["Event Type"] == i) & (df1['DayOfWeek']=="Thursday")])
  c5 = len(df1[(df1["Event Type"] == i) & (df1['DayOfWeek']=="Friday")])
  c6 = len(df1[(df1["Event Type"] == i) & (df1['DayOfWeek']=="Saturday")])
  c7 = len(df1[(df1["Event Type"] == i) & (df1['DayOfWeek']=="Sunday")])


  plt.figure(figsize=(8,5))
  Days=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
  nocases=[c1,c2,c3,c4,c5,c6,c7]
    
  plt.figure(figsize=(8,5))
  Days=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
  nocases=[c1,c2,c3,c4,c5,c6,c7]


    # plt.plot(day,delhi_temperature,"mo--",linewidth=3 ,markersize=10,label="delhi_Temp line")
  plt.plot(days,nocases,"yo:",linewidth=3 ,markersize=10,label="Level of Cases")
  plt.title("Day wise cases",fontsize=15) #changes fontsize of the text
  plt.xlabel("Days",fontsize=13)        
  plt.ylabel("Number of cases",fontsize=13)
  plt.legend(loc=4) #set the location of the text
  plt.grid(color='w', linestyle='-.', linewidth=5)

# %% [markdown]
# # No of Events Updated by Date

# %%
df1['Date'].value_counts().plot(kind='line', figsize=(20, 10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9728/3615818663.py in <module>
# ----> 1 df1['Date'].value_counts().plot(kind='line', figsize=(20, 10))
#
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Date'
